# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Subplot With Different Axis

# %%
plt.style.use('seaborn')

plt.gca() #Get Current Axis
plt.gcf() #Get Current Figure

data = pd.read_csv('subp.csv')
ages = data['Age']
dev_salaries = data['All_Devs']
py_salaries = data['Python']
js_salaries = data['JavaScript']

fig, (ax1,ax2) = plt.subplots(nrows=2, ncols=1, sharex=True)  
#For making subplots, we need to set it to a figure and an axis
#Above example, we set two rows of graphs and one column
#One figure will have 2 graphs, as 2x1 = 2
#sharex and sharey means both will share the same axis

ax1.plot(ages, py_salaries, label='Python')
ax1.plot(ages, js_salaries, label='JavaScript')

ax2.plot(ages, dev_salaries, color='#444444',
         linestyle='--', label='All Devs')

ax1.legend()

#Above is for the first graph

ax1.set_title('Median Salary (USD) by Age')
ax1.set_ylabel('Median Salary (USD)')

ax2.legend()

ax2.set_xlabel('Ages')
ax2.set_ylabel('Median Salary (USD)')

#Above is for the second graph

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Subplot with different Figs

# %%
plt.style.use('seaborn')

data = pd.read_csv('subp.csv')
ages = data['Age']
dev_salaries = data['All_Devs']
py_salaries = data['Python']
js_salaries = data['JavaScript']

fig1, ax1 = plt.subplots()
fig2, ax2 = plt.subplots()
#Two separate figures
#Fig 1 will have ax1 (graph 1)
#Fig 2 will have ax2 (graph 2)

ax1.plot(ages, py_salaries, label='Python')
ax1.plot(ages, js_salaries, label='JavaScript')

ax2.plot(ages, dev_salaries, color='#444444',
         linestyle='--', label='All Devs')

ax1.legend()

ax1.set_title('Median Salary (USD) by Age')
ax1.set_ylabel('Median Salary (USD)')

ax2.legend()

ax2.set_xlabel('Ages')
ax2.set_ylabel('Median Salary (USD)')


plt.tight_layout()

plt.show()

# fig1.savefig('fig1.png')
# fig2.savefig('fig2.png')
#Saving the figure
